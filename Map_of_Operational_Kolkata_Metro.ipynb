# %%
from collections import defaultdict as dd

green_line=[("Howrah Maidan",0),("Howrah Railway Station",1),("Mahakaran",2),("Esplanade",3),("Sealdah",4),
("Phoolbagan",5), ("Salt Lake Stadium",6),("Bengal Chemical",7),("City Centre I",8),("Central Park",9),
("Korunamoyee"),70)("Salt Lake Sector V",10)]

adj_list=dd(list)
for i in range(len(green_line)-1):
    stn1=green_line[i]
    stn2=green_line[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70)]

# %%
from collections import defaultdict as dd

blue_line=[("Dakshineshwar",11),("Baranagar",12),("Noapara",13),("Dum Dum",14),("Belgachhia",15),("Shyambazar",16),
("Sovabazar Sutanuti",17),("Girish Park",18),("Mahatma Gandhi Road",19),("Central",20),("Chandni Chowk",21),
("Esplanade",3),("Park Street",22),("Maidan",23),("Rabindra Sadan",24),("Netaji Bhavan",25),("Jatin Das Park",26),
("Kalighat",27),("Rabindra Sarovar",28),("Mahanayak Uttam Kumar",29),("Netaji",30),("Masterda Surya Sen",31),
("Gitanjali",32),("Kavi Nazrul",33),("Shahid Khudiram",34),("Kavi Subhas",35)]

for i in range(len(blue_line)-1):
    stn1=blue_line[i]
    stn2=blue_line[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4), ('Chandni Chowk', 21), ('Park Street', 22)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70)]
# ('Dakshineshwar', 11)->[('Baranagar', 12)]
# ('Baranagar', 12)->[('Dakshineshwar', 11), ('Noapara', 13)]
# ('Noapara', 13)->[('Baranagar', 12), ('Dum Dum', 14)]
# ('Dum Dum', 14)->[('Noapara', 13), ('Belgachhia', 15)]
# ('Belgachhia', 15)->[('Dum Dum', 14), ('Shyambazar', 16)]
# ('Shyambazar', 16)->[('Belgachhia', 15), ('Sovabazar Sutanuti', 17)]
# ('Sovabazar Sutanuti', 17)->[('Shyambazar', 16), ('Girish Park', 18)]
# ('Girish Park', 18)->[('Sovabazar Sutanuti', 17), ('Mahatma Gandhi Road', 19)]
# ('Mahatma Gandhi Road', 19)->[('Girish Park', 18), ('Central', 20)]
# ('Central', 20)->[('Mahatma Gandhi Road', 19), ('Chandni Chowk', 21)]
# ('Chandni Chowk', 21)->[('Central', 20), ('Esplanade', 3)]
# ('Park Street', 22)->[('Esplanade', 3), ('Maidan', 23)]
# ('Maidan', 23)->[('Park Street', 22), ('Rabindra Sadan', 24)]
# ('Rabindra Sadan', 24)->[('Maidan', 23), ('Netaji Bhavan', 25)]
# ('Netaji Bhavan', 25)->[('Rabindra Sadan', 24), ('Jatin Das Park', 26)]
# ('Jatin Das Park', 26)->[('Netaji Bhavan', 25), ('Kalighat', 27)]
# ('Kalighat', 27)->[('Jatin Das Park', 26), ('Rabindra Sarovar', 28)]
# ('Rabindra Sarovar', 28)->[('Kalighat', 27), ('Mahanayak Uttam Kumar', 29)]
# ('Mahanayak Uttam Kumar', 29)->[('Rabindra Sarovar', 28), ('Netaji', 30)]
# ('Netaji', 30)->[('Mahanayak Uttam Kumar', 29), ('Masterda Surya Sen', 31)]
# ('Masterda Surya Sen', 31)->[('Netaji', 30), ('Gitanjali', 32)]
# ('Gitanjali', 32)->[('Masterda Surya Sen', 31), ('Kavi Nazrul', 33)]
# ('Kavi Nazrul', 33)->[('Gitanjali', 32), ('Shahid Khudiram', 34)]
# ('Shahid Khudiram', 34)->[('Kavi Nazrul', 33), ('Kavi Subhas', 35)]
# ('Kavi Subhas', 35)->[('Shahid Khudiram', 34)]

# %%
from collections import defaultdict as dd

purple_line=[("Joka",36),("Thakurpukur",37),("Sakherbazar",38),("Behala Chowrasta",39),("Behala Bazar",40),("Taratala",41),
("Majerhat",42)]

for i in range(len(purple_line)-1):
    stn1=purple_line[i]
    stn2=purple_line[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4), ('Chandni Chowk', 21), ('Park Street', 22)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70)]
# ('Dakshineshwar', 11)->[('Baranagar', 12)]
# ('Baranagar', 12)->[('Dakshineshwar', 11), ('Noapara', 13)]
# ('Noapara', 13)->[('Baranagar', 12), ('Dum Dum', 14)]
# ('Dum Dum', 14)->[('Noapara', 13), ('Belgachhia', 15)]
# ('Belgachhia', 15)->[('Dum Dum', 14), ('Shyambazar', 16)]
# ('Shyambazar', 16)->[('Belgachhia', 15), ('Sovabazar Sutanuti', 17)]
# ('Sovabazar Sutanuti', 17)->[('Shyambazar', 16), ('Girish Park', 18)]
# ('Girish Park', 18)->[('Sovabazar Sutanuti', 17), ('Mahatma Gandhi Road', 19)]
# ('Mahatma Gandhi Road', 19)->[('Girish Park', 18), ('Central', 20)]
# ('Central', 20)->[('Mahatma Gandhi Road', 19), ('Chandni Chowk', 21)]
# ('Chandni Chowk', 21)->[('Central', 20), ('Esplanade', 3)]
# ('Park Street', 22)->[('Esplanade', 3), ('Maidan', 23)]
# ('Maidan', 23)->[('Park Street', 22), ('Rabindra Sadan', 24)]
# ('Rabindra Sadan', 24)->[('Maidan', 23), ('Netaji Bhavan', 25)]
# ('Netaji Bhavan', 25)->[('Rabindra Sadan', 24), ('Jatin Das Park', 26)]
# ('Jatin Das Park', 26)->[('Netaji Bhavan', 25), ('Kalighat', 27)]
# ('Kalighat', 27)->[('Jatin Das Park', 26), ('Rabindra Sarovar', 28)]
# ('Rabindra Sarovar', 28)->[('Kalighat', 27), ('Mahanayak Uttam Kumar', 29)]
# ('Mahanayak Uttam Kumar', 29)->[('Rabindra Sarovar', 28), ('Netaji', 30)]
# ('Netaji', 30)->[('Mahanayak Uttam Kumar', 29), ('Masterda Surya Sen', 31)]
# ('Masterda Surya Sen', 31)->[('Netaji', 30), ('Gitanjali', 32)]
# ('Gitanjali', 32)->[('Masterda Surya Sen', 31), ('Kavi Nazrul', 33)]
# ('Kavi Nazrul', 33)->[('Gitanjali', 32), ('Shahid Khudiram', 34)]
# ('Shahid Khudiram', 34)->[('Kavi Nazrul', 33), ('Kavi Subhas', 35)]
# ('Kavi Subhas', 35)->[('Shahid Khudiram', 34)]
# ('Joka', 36)->[('Thakurpukur', 37)]
# ('Thakurpukur', 37)->[('Joka', 36), ('Sakherbazar', 38)]
# ('Sakherbazar', 38)->[('Thakurpukur', 37), ('Behala Chowrasta', 39)]
# ('Behala Chowrasta', 39)->[('Sakherbazar', 38), ('Behala Bazar', 40)]
# ('Behala Bazar', 40)->[('Behala Chowrasta', 39), ('Taratala', 41)]
# ('Taratala', 41)->[('Behala Bazar', 40), ('Majerhat', 42)]
# ('Majerhat', 42)->[('Taratala', 41)]

# %%
from collections import defaultdict as dd

orange_line=[("Kavi Subhas",35),("Satyajit Ray",43),("Jyotirindra Nath Nandy",44),("Kavi Sukanta",45),
("Hemanta Mukherjee",46)]

for i in range(len(orange_line)-1):
    stn1=orange_line[i]
    stn2=orange_line[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4), ('Chandni Chowk', 21), ('Park Street', 22)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70)]
# ('Dakshineshwar', 11)->[('Baranagar', 12)]
# ('Baranagar', 12)->[('Dakshineshwar', 11), ('Noapara', 13)]
# ('Noapara', 13)->[('Baranagar', 12), ('Dum Dum', 14)]
# ('Dum Dum', 14)->[('Noapara', 13), ('Belgachhia', 15)]
# ('Belgachhia', 15)->[('Dum Dum', 14), ('Shyambazar', 16)]
# ('Shyambazar', 16)->[('Belgachhia', 15), ('Sovabazar Sutanuti', 17)]
# ('Sovabazar Sutanuti', 17)->[('Shyambazar', 16), ('Girish Park', 18)]
# ('Girish Park', 18)->[('Sovabazar Sutanuti', 17), ('Mahatma Gandhi Road', 19)]
# ('Mahatma Gandhi Road', 19)->[('Girish Park', 18), ('Central', 20)]
# ('Central', 20)->[('Mahatma Gandhi Road', 19), ('Chandni Chowk', 21)]
# ('Chandni Chowk', 21)->[('Central', 20), ('Esplanade', 3)]
# ('Park Street', 22)->[('Esplanade', 3), ('Maidan', 23)]
# ('Maidan', 23)->[('Park Street', 22), ('Rabindra Sadan', 24)]
# ('Rabindra Sadan', 24)->[('Maidan', 23), ('Netaji Bhavan', 25)]
# ('Netaji Bhavan', 25)->[('Rabindra Sadan', 24), ('Jatin Das Park', 26)]
# ('Jatin Das Park', 26)->[('Netaji Bhavan', 25), ('Kalighat', 27)]
# ('Kalighat', 27)->[('Jatin Das Park', 26), ('Rabindra Sarovar', 28)]
# ('Rabindra Sarovar', 28)->[('Kalighat', 27), ('Mahanayak Uttam Kumar', 29)]
# ('Mahanayak Uttam Kumar', 29)->[('Rabindra Sarovar', 28), ('Netaji', 30)]
# ('Netaji', 30)->[('Mahanayak Uttam Kumar', 29), ('Masterda Surya Sen', 31)]
# ('Masterda Surya Sen', 31)->[('Netaji', 30), ('Gitanjali', 32)]
# ('Gitanjali', 32)->[('Masterda Surya Sen', 31), ('Kavi Nazrul', 33)]
# ('Kavi Nazrul', 33)->[('Gitanjali', 32), ('Shahid Khudiram', 34)]
# ('Shahid Khudiram', 34)->[('Kavi Nazrul', 33), ('Kavi Subhas', 35)]
# ('Kavi Subhas', 35)->[('Shahid Khudiram', 34), ('Satyajit Ray', 43)]
# ('Joka', 36)->[('Thakurpukur', 37)]
# ('Thakurpukur', 37)->[('Joka', 36), ('Sakherbazar', 38)]
# ('Sakherbazar', 38)->[('Thakurpukur', 37), ('Behala Chowrasta', 39)]
# ('Behala Chowrasta', 39)->[('Sakherbazar', 38), ('Behala Bazar', 40)]
# ('Behala Bazar', 40)->[('Behala Chowrasta', 39), ('Taratala', 41)]
# ('Taratala', 41)->[('Behala Bazar', 40), ('Majerhat', 42)]
# ('Majerhat', 42)->[('Taratala', 41)]
# ('Satyajit Ray', 43)->[('Kavi Subhas', 35), ('Jyotirindra Nath Nandy', 44)]
# ('Jyotirindra Nath Nandy', 44)->[('Satyajit Ray', 43), ('Kavi Sukanta', 45)]
# ('Kavi Sukanta', 45)->[('Jyotirindra Nath Nandy', 44), ('Hemanta Mukherjee', 46)]
# ('Hemanta Mukherjee', 46)->[('Kavi Sukanta', 45)]

# %%
from collections import defaultdict as dd

purple_line_ext=[("Mominpur",47),("Khidderpore",48),("Victoria Memorial",49),("Park Street",22),("Esplanade",3)]

for i in range(len(purple_line_ext)-1):
    stn1=purple_line_ext[i]
    stn2=purple_line_ext[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4), ('Chandni Chowk', 21), ('Park Street', 22), ('Park Street', 22)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70)]
# ('Dakshineshwar', 11)->[('Baranagar', 12)]
# ('Baranagar', 12)->[('Dakshineshwar', 11), ('Noapara', 13)]
# ('Noapara', 13)->[('Baranagar', 12), ('Dum Dum', 14)]
# ('Dum Dum', 14)->[('Noapara', 13), ('Belgachhia', 15)]
# ('Belgachhia', 15)->[('Dum Dum', 14), ('Shyambazar', 16)]
# ('Shyambazar', 16)->[('Belgachhia', 15), ('Sovabazar Sutanuti', 17)]
# ('Sovabazar Sutanuti', 17)->[('Shyambazar', 16), ('Girish Park', 18)]
# ('Girish Park', 18)->[('Sovabazar Sutanuti', 17), ('Mahatma Gandhi Road', 19)]
# ('Mahatma Gandhi Road', 19)->[('Girish Park', 18), ('Central', 20)]
# ('Central', 20)->[('Mahatma Gandhi Road', 19), ('Chandni Chowk', 21)]
# ('Chandni Chowk', 21)->[('Central', 20), ('Esplanade', 3)]
# ('Park Street', 22)->[('Esplanade', 3), ('Maidan', 23), ('Victoria Memorial', 49), ('Esplanade', 3)]
# ('Maidan', 23)->[('Park Street', 22), ('Rabindra Sadan', 24)]
# ('Rabindra Sadan', 24)->[('Maidan', 23), ('Netaji Bhavan', 25)]
# ('Netaji Bhavan', 25)->[('Rabindra Sadan', 24), ('Jatin Das Park', 26)]
# ('Jatin Das Park', 26)->[('Netaji Bhavan', 25), ('Kalighat', 27)]
# ('Kalighat', 27)->[('Jatin Das Park', 26), ('Rabindra Sarovar', 28)]
# ('Rabindra Sarovar', 28)->[('Kalighat', 27), ('Mahanayak Uttam Kumar', 29)]
# ('Mahanayak Uttam Kumar', 29)->[('Rabindra Sarovar', 28), ('Netaji', 30)]
# ('Netaji', 30)->[('Mahanayak Uttam Kumar', 29), ('Masterda Surya Sen', 31)]
# ('Masterda Surya Sen', 31)->[('Netaji', 30), ('Gitanjali', 32)]
# ('Gitanjali', 32)->[('Masterda Surya Sen', 31), ('Kavi Nazrul', 33)]
# ('Kavi Nazrul', 33)->[('Gitanjali', 32), ('Shahid Khudiram', 34)]
# ('Shahid Khudiram', 34)->[('Kavi Nazrul', 33), ('Kavi Subhas', 35)]
# ('Kavi Subhas', 35)->[('Shahid Khudiram', 34), ('Satyajit Ray', 43)]
# ('Joka', 36)->[('Thakurpukur', 37)]
# ('Thakurpukur', 37)->[('Joka', 36), ('Sakherbazar', 38)]
# ('Sakherbazar', 38)->[('Thakurpukur', 37), ('Behala Chowrasta', 39)]
# ('Behala Chowrasta', 39)->[('Sakherbazar', 38), ('Behala Bazar', 40)]
# ('Behala Bazar', 40)->[('Behala Chowrasta', 39), ('Taratala', 41)]
# ('Taratala', 41)->[('Behala Bazar', 40), ('Majerhat', 42)]
# ('Majerhat', 42)->[('Taratala', 41)]
# ('Satyajit Ray', 43)->[('Kavi Subhas', 35), ('Jyotirindra Nath Nandy', 44)]
# ('Jyotirindra Nath Nandy', 44)->[('Satyajit Ray', 43), ('Kavi Sukanta', 45)]
# ('Kavi Sukanta', 45)->[('Jyotirindra Nath Nandy', 44), ('Hemanta Mukherjee', 46)]
# ('Hemanta Mukherjee', 46)->[('Kavi Sukanta', 45)]
# ('Mominpur', 47)->[('Khidderpore', 48)]
# ('Khidderpore', 48)->[('Mominpur', 47), ('Victoria Memorial', 49)]
# ('Victoria Memorial', 49)->[('Khidderpore', 48), ('Park Street', 22)]

# %%
from collections import defaultdict as dd

yellow_line=[("Noapara",13),("Dum Dum Cantonment",50),("Jessore Road",51),("Biman Bandar",52)]

for i in range(len(yellow_line)-1):
    stn1=yellow_line[i]
    stn2=yellow_line[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4), ('Chandni Chowk', 21), ('Park Street', 22), ('Park Street', 22)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70)]
# ('Dakshineshwar', 11)->[('Baranagar', 12)]
# ('Baranagar', 12)->[('Dakshineshwar', 11), ('Noapara', 13)]
# ('Noapara', 13)->[('Baranagar', 12), ('Dum Dum', 14), ('Dum Dum Cantonment', 50)]
# ('Dum Dum', 14)->[('Noapara', 13), ('Belgachhia', 15)]
# ('Belgachhia', 15)->[('Dum Dum', 14), ('Shyambazar', 16)]
# ('Shyambazar', 16)->[('Belgachhia', 15), ('Sovabazar Sutanuti', 17)]
# ('Sovabazar Sutanuti', 17)->[('Shyambazar', 16), ('Girish Park', 18)]
# ('Girish Park', 18)->[('Sovabazar Sutanuti', 17), ('Mahatma Gandhi Road', 19)]
# ('Mahatma Gandhi Road', 19)->[('Girish Park', 18), ('Central', 20)]
# ('Central', 20)->[('Mahatma Gandhi Road', 19), ('Chandni Chowk', 21)]
# ('Chandni Chowk', 21)->[('Central', 20), ('Esplanade', 3)]
# ('Park Street', 22)->[('Esplanade', 3), ('Maidan', 23), ('Victoria Memorial', 49), ('Esplanade', 3)]
# ('Maidan', 23)->[('Park Street', 22), ('Rabindra Sadan', 24)]
# ('Rabindra Sadan', 24)->[('Maidan', 23), ('Netaji Bhavan', 25)]
# ('Netaji Bhavan', 25)->[('Rabindra Sadan', 24), ('Jatin Das Park', 26)]
# ('Jatin Das Park', 26)->[('Netaji Bhavan', 25), ('Kalighat', 27)]
# ('Kalighat', 27)->[('Jatin Das Park', 26), ('Rabindra Sarovar', 28)]
# ('Rabindra Sarovar', 28)->[('Kalighat', 27), ('Mahanayak Uttam Kumar', 29)]
# ('Mahanayak Uttam Kumar', 29)->[('Rabindra Sarovar', 28), ('Netaji', 30)]
# ('Netaji', 30)->[('Mahanayak Uttam Kumar', 29), ('Masterda Surya Sen', 31)]
# ('Masterda Surya Sen', 31)->[('Netaji', 30), ('Gitanjali', 32)]
# ('Gitanjali', 32)->[('Masterda Surya Sen', 31), ('Kavi Nazrul', 33)]
# ('Kavi Nazrul', 33)->[('Gitanjali', 32), ('Shahid Khudiram', 34)]
# ('Shahid Khudiram', 34)->[('Kavi Nazrul', 33), ('Kavi Subhas', 35)]
# ('Kavi Subhas', 35)->[('Shahid Khudiram', 34), ('Satyajit Ray', 43)]
# ('Joka', 36)->[('Thakurpukur', 37)]
# ('Thakurpukur', 37)->[('Joka', 36), ('Sakherbazar', 38)]
# ('Sakherbazar', 38)->[('Thakurpukur', 37), ('Behala Chowrasta', 39)]
# ('Behala Chowrasta', 39)->[('Sakherbazar', 38), ('Behala Bazar', 40)]
# ('Behala Bazar', 40)->[('Behala Chowrasta', 39), ('Taratala', 41)]
# ('Taratala', 41)->[('Behala Bazar', 40), ('Majerhat', 42)]
# ('Majerhat', 42)->[('Taratala', 41)]
# ('Satyajit Ray', 43)->[('Kavi Subhas', 35), ('Jyotirindra Nath Nandy', 44)]
# ('Jyotirindra Nath Nandy', 44)->[('Satyajit Ray', 43), ('Kavi Sukanta', 45)]
# ('Kavi Sukanta', 45)->[('Jyotirindra Nath Nandy', 44), ('Hemanta Mukherjee', 46)]
# ('Hemanta Mukherjee', 46)->[('Kavi Sukanta', 45)]
# ('Mominpur', 47)->[('Khidderpore', 48)]
# ('Khidderpore', 48)->[('Mominpur', 47), ('Victoria Memorial', 49)]
# ('Victoria Memorial', 49)->[('Khidderpore', 48), ('Park Street', 22)]
# ('Dum Dum Cantonment', 50)->[('Noapara', 13), ('Jessore Road', 51)]
# ('Jessore Road', 51)->[('Dum Dum Cantonment', 50), ('Biman Bandar', 52)]
# ('Biman Bandar', 52)->[('Jessore Road', 51)]

# %%
from collections import defaultdict as dd

orange_line_ext=[("VIP Bazar",53),("Ritwik Ghatak",54),("Barun Sengupta",55),("Beliaghata",56),("Gour Kishore Ghosh",57),
("NICCO Park",58),("Salt Lake Sector V",10),("Technopolis",59),("Nazrul Tirtha",60),("Swapno Bhor",61),
("Biswa Bangla Convention Centre",62),("Kala Kshetra",63),("Mother's Wax Museum",64),("Eco Park",65),
("Siksha Tirtha",66),("City Centre II",67),("Chinar Park",68),("VIP Road",69),("Biman Bandar",52)]

for i in range(len(orange_line_ext)-1):
    stn1=orange_line_ext[i]
    stn2=orange_line_ext[i+1]
    adj_list[stn1].append(stn2)
    adj_list[stn2].append(stn1)

for i,j in adj_list.items():
    print(f"{i}->{j}")
# Out:
# ('Howrah Maidan', 0)->[('Howrah Railway Station', 1)]
# ('Howrah Railway Station', 1)->[('Howrah Maidan', 0), ('Mahakaran', 2)]
# ('Mahakaran', 2)->[('Howrah Railway Station', 1), ('Esplanade', 3)]
# ('Esplanade', 3)->[('Mahakaran', 2), ('Sealdah', 4), ('Chandni Chowk', 21), ('Park Street', 22), ('Park Street', 22)]
# ('Sealdah', 4)->[('Esplanade', 3), ('Phoolbagan', 5)]
# ('Phoolbagan', 5)->[('Sealdah', 4), ('Salt Lake Stadium', 6)]
# ('Salt Lake Stadium', 6)->[('Phoolbagan', 5), ('Bengal Chemical', 7)]
# ('Bengal Chemical', 7)->[('Salt Lake Stadium', 6), ('City Centre I', 8)]
# ('City Centre I', 8)->[('Bengal Chemical', 7), ('Central Park', 9)]
# ('Central Park', 9)->[('City Centre I', 8), ('Korunamoyee', 70)]
# ('Korunamoyee', 70)->[('Central Park', 9), ('Salt Lake Sector V', 10)]
# ('Salt Lake Sector V', 10)->[('Korunamoyee', 70), ('NICCO Park', 58), ('Technopolis', 59)]
# ('Dakshineshwar', 11)->[('Baranagar', 12)]
# ('Baranagar', 12)->[('Dakshineshwar', 11), ('Noapara', 13)]
# ('Noapara', 13)->[('Baranagar', 12), ('Dum Dum', 14), ('Dum Dum Cantonment', 50)]
# ('Dum Dum', 14)->[('Noapara', 13), ('Belgachhia', 15)]
# ('Belgachhia', 15)->[('Dum Dum', 14), ('Shyambazar', 16)]
# ('Shyambazar', 16)->[('Belgachhia', 15), ('Sovabazar Sutanuti', 17)]
# ('Sovabazar Sutanuti', 17)->[('Shyambazar', 16), ('Girish Park', 18)]
# ('Girish Park', 18)->[('Sovabazar Sutanuti', 17), ('Mahatma Gandhi Road', 19)]
# ('Mahatma Gandhi Road', 19)->[('Girish Park', 18), ('Central', 20)]
# ('Central', 20)->[('Mahatma Gandhi Road', 19), ('Chandni Chowk', 21)]
# ('Chandni Chowk', 21)->[('Central', 20), ('Esplanade', 3)]
# ('Park Street', 22)->[('Esplanade', 3), ('Maidan', 23), ('Victoria Memorial', 49), ('Esplanade', 3)]
# ('Maidan', 23)->[('Park Street', 22), ('Rabindra Sadan', 24)]
# ('Rabindra Sadan', 24)->[('Maidan', 23), ('Netaji Bhavan', 25)]
# ('Netaji Bhavan', 25)->[('Rabindra Sadan', 24), ('Jatin Das Park', 26)]
# ('Jatin Das Park', 26)->[('Netaji Bhavan', 25), ('Kalighat', 27)]
# ('Kalighat', 27)->[('Jatin Das Park', 26), ('Rabindra Sarovar', 28)]
# ('Rabindra Sarovar', 28)->[('Kalighat', 27), ('Mahanayak Uttam Kumar', 29)]
# ('Mahanayak Uttam Kumar', 29)->[('Rabindra Sarovar', 28), ('Netaji', 30)]
# ('Netaji', 30)->[('Mahanayak Uttam Kumar', 29), ('Masterda Surya Sen', 31)]
# ('Masterda Surya Sen', 31)->[('Netaji', 30), ('Gitanjali', 32)]
# ('Gitanjali', 32)->[('Masterda Surya Sen', 31), ('Kavi Nazrul', 33)]
# ('Kavi Nazrul', 33)->[('Gitanjali', 32), ('Shahid Khudiram', 34)]
# ('Shahid Khudiram', 34)->[('Kavi Nazrul', 33), ('Kavi Subhas', 35)]
# ('Kavi Subhas', 35)->[('Shahid Khudiram', 34), ('Satyajit Ray', 43)]
# ('Joka', 36)->[('Thakurpukur', 37)]
# ('Thakurpukur', 37)->[('Joka', 36), ('Sakherbazar', 38)]
# ('Sakherbazar', 38)->[('Thakurpukur', 37), ('Behala Chowrasta', 39)]
# ('Behala Chowrasta', 39)->[('Sakherbazar', 38), ('Behala Bazar', 40)]
# ('Behala Bazar', 40)->[('Behala Chowrasta', 39), ('Taratala', 41)]
# ('Taratala', 41)->[('Behala Bazar', 40), ('Majerhat', 42)]
# ('Majerhat', 42)->[('Taratala', 41)]
# ('Satyajit Ray', 43)->[('Kavi Subhas', 35), ('Jyotirindra Nath Nandy', 44)]
# ('Jyotirindra Nath Nandy', 44)->[('Satyajit Ray', 43), ('Kavi Sukanta', 45)]
# ('Kavi Sukanta', 45)->[('Jyotirindra Nath Nandy', 44), ('Hemanta Mukherjee', 46)]
# ('Hemanta Mukherjee', 46)->[('Kavi Sukanta', 45)]
# ('Mominpur', 47)->[('Khidderpore', 48)]
# ('Khidderpore', 48)->[('Mominpur', 47), ('Victoria Memorial', 49)]
# ('Victoria Memorial', 49)->[('Khidderpore', 48), ('Park Street', 22)]
# ('Dum Dum Cantonment', 50)->[('Noapara', 13), ('Jessore Road', 51)]
# ('Jessore Road', 51)->[('Dum Dum Cantonment', 50), ('Biman Bandar', 52)]
# ('Biman Bandar', 52)->[('Jessore Road', 51), ('VIP Road', 69)]
# ('VIP Bazar', 53)->[('Ritwik Ghatak', 54)]
# ('Ritwik Ghatak', 54)->[('VIP Bazar', 53), ('Barun Sengupta', 55)]
# ('Barun Sengupta', 55)->[('Ritwik Ghatak', 54), ('Beliaghata', 56)]
# ('Beliaghata', 56)->[('Barun Sengupta', 55), ('Gour Kishore Ghosh', 57)]
# ('Gour Kishore Ghosh', 57)->[('Beliaghata', 56), ('NICCO Park', 58)]
# ('NICCO Park', 58)->[('Gour Kishore Ghosh', 57), ('Salt Lake Sector V', 10)]
# ('Technopolis', 59)->[('Salt Lake Sector V', 10), ('Nazrul Tirtha', 60)]
# ('Nazrul Tirtha', 60)->[('Technopolis', 59), ('Swapno Bhor', 61)]
# ('Swapno Bhor', 61)->[('Nazrul Tirtha', 60), ('Biswa Bangla Convention Centre', 62)]
# ('Biswa Bangla Convention Centre', 62)->[('Swapno Bhor', 61), ('Kala Kshetra', 63)]
# ('Kala Kshetra', 63)->[('Biswa Bangla Convention Centre', 62), ("Mother's Wax Museum", 64)]
# ("Mother's Wax Museum", 64)->[('Kala Kshetra', 63), ('Eco Park', 65)]
# ('Eco Park', 65)->[("Mother's Wax Museum", 64), ('Siksha Tirtha', 66)]
# ('Siksha Tirtha', 66)->[('Eco Park', 65), ('City Centre II', 67)]
# ('City Centre II', 67)->[('Siksha Tirtha', 66), ('Chinar Park', 68)]
# ('Chinar Park', 68)->[('City Centre II', 67), ('VIP Road', 69)]
# ('VIP Road', 69)->[('Chinar Park', 68), ('Biman Bandar', 52)]

# %%
import pandas as pd

data=[]
for i,j in adj_list.items():
  str=", ".join([f"{next[0]} ({next[1]})" for next in j])
  data.append({"Station":f"{i[0]}({[i[1]]})","Connected Stations":str})

temp=pd.DataFrame(data)
temp.to_csv("Kolkata_Metro_Adjacency_List.csv",index=False)

print(temp)
# Out:
#                         Station  \
# 0            Howrah Maidan([0])
# 1   Howrah Railway Station([1])
# 2                Mahakaran([2])
# 3                Esplanade([3])
# 4                  Sealdah([4])
# ..                          ...
# 66               Eco Park([65])
# 67          Siksha Tirtha([66])
# 68         City Centre II([67])
# 69            Chinar Park([68])
# 70               VIP Road([69])
#
#                                    Connected Stations
# 0                          Howrah Railway Station (1)
# 1                    Howrah Maidan (0), Mahakaran (2)
# 2           Howrah Railway Station (1), Esplanade (3)
# 3   Mahakaran (2), Sealdah (4), Chandni Chowk (21)...
# 4                       Esplanade (3), Phoolbagan (5)
# ..                                                ...
# 66       Mother's Wax Museum (64), Siksha Tirtha (66)
# 67                 Eco Park (65), City Centre II (67)
# 68               Siksha Tirtha (66), Chinar Park (68)
# 69                 City Centre II (67), VIP Road (69)
# 70                Chinar Park (68), Biman Bandar (52)
#
# [71 rows x 2 columns]

# %%
# !pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from adjustText) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from adjustText) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from adjustText) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: adjustText
# Successfully installed adjustText-1.3.0

# %%
from adjustText import adjust_text as at
import networkx as nx
import matplotlib.pyplot as plt

def add_edges_with_color(line, color):
    for i in range(len(line) - 1):
        node1, node2 = line[i][0], line[i + 1][0]
        if not G.has_edge(node1, node2):
            G.add_edge(node1, node2, color=color)

G=nx.Graph()

color_map = {
    'green': "green",
    'blue': "blue",
    'purple': "purple",
    'silver': "silver",
    'yellow': "yellow",
    'orange': "orange",
    'gold': "gold"
}

node_color = {}


add_edges_with_color(blue_line, color_map['blue'])
add_edges_with_color(green_line, color_map['green'])
add_edges_with_color(purple_line, color_map['purple'])
add_edges_with_color(purple_line_ext, color_map['silver'])
add_edges_with_color(yellow_line, color_map['yellow'])
add_edges_with_color(orange_line, color_map['orange'])
add_edges_with_color(orange_line_ext, color_map['gold'])

edge_colors = [G[u][v]['color'] for u, v in G.edges()]

plt.figure(figsize=(15, 10))
pos = nx.kamada_kawai_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=10)
nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=2)
#nx.draw_networkx_labels(G, pos, font_size=6)

'''texts = []
for i, node in enumerate(G.nodes()):
    x, y = pos[node]
    y_offset = 0.015 if i % 2 == 0 else -0.015
    text = plt.text(x, y + y_offset, node, fontsize=6, ha='right', va='bottom') if i%2==0 else plt.text(x, y + y_offset, node, fontsize=6, ha='left', va='top')
    texts.append(text)
'''
texts = []
for i, node in enumerate(G.nodes()):
    x, y = pos[node]
    y_offset = 0.015 if i % 2 == 0 else -0.015
    text = plt.text(x, y + y_offset, node, fontsize=6, ha='center', va='bottom' if i % 2 == 0 else 'top')
    texts.append(text)

    # Draw arrow pointing to the node
    plt.annotate("", xy=(x, y), xytext=(x, y + y_offset),
                 arrowprops=dict(arrowstyle="->", color='gray', lw=0.5))


plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

green_line = [("Howrah Maidan", 0), ("Howrah Railway Station", 1), ("Mahakaran", 2),
              ("Esplanade", 3),("Sealdah", 4), ("Phoolbagan", 5), ("Salt Lake Stadium", 6),
              ("Bengal Chemical", 7), ("City Centre I", 8), ("Central Park", 9), ("Korunamoyee",70),
              ("Salt Lake Sector V", 10)]

blue_line = [("Dakshineshwar", 11),("Baranagar", 12), ("Noapara", 13), ("Dum Dum", 14),
              ("Belgachhia", 15), ("Shyambazar", 16), ("Sovabazar Sutanuti", 17),
              ("Girish Park", 18), ("Mahatma Gandhi Road", 19), ("Central", 20),
              ("Chandni Chowk", 21), ("Esplanade", 3), ("Park Street", 22),
              ("Maidan", 23), ("Rabindra Sadan", 24), ("Netaji Bhavan", 25),
              ("Jatin Das Park", 26), ("Kalighat", 27), ("Rabindra Sarovar", 28),
              ("Mahanayak Uttam Kumar", 29), ("Netaji", 30), ("Masterda Surya Sen", 31),
              ("Gitanjali", 32), ("Kavi Nazrul", 33), ("Shahid Khudiram", 34),
              ("Kavi Subhas", 35)]

purple_line=[("Joka",36),("Thakurpukur",37),("Sakherbazar",38),("Behala Chowrasta",39),
              ("Behala Bazar",40),("Taratala",41),("Majerhat",42)]

orange_line=[("Kavi Subhas",35),("Satyajit Ray",43),("Jyotirindra Nath Nandy",44),
              ("Kavi Sukanta",45),("Hemanta Mukherjee",46)]

def add_edges(line, color):
    for i in range(len(line) - 1):
        node1, node2 = line[i][0], line[i + 1][0]
        G.add_edge(node1, node2, color=color)

add_edges(green_line, "green")
add_edges(blue_line,"blue")
add_edges(purple_line,"purple")
add_edges(orange_line,"orange")

pos = {
    "Howrah Maidan": (0, 0),
    "Howrah Railway Station": (0, -1),
    "Mahakaran": (0, -2),
    "Esplanade": (0, -3),
    "Sealdah": (0, -4),
    "Phoolbagan": (0, -5),
    "Salt Lake Stadium": (0, -6),
    "Bengal Chemical": (0, -7),
    "City Centre I": (0, -8),
    "Central Park": (0, -9),
    "Korunamoyee": (0, -10),
    "Salt Lake Sector V": (0, -11),
    #End of Green
    #Start of Blue
    "Dakshineshwar": (1,8),
    "Baranagar": (1,7),
    "Noapara": (1,6),
    "Dum Dum": (1,5),
    "Belgachhia": (1,4),
    "Shyambazar": (1,3),
    "Sovabazar Sutanuti": (1,2),
    "Girish Park": (1,1),
    "Mahatma Gandhi Road": (1,0),
    "Central": (1,-1),
    "Chandni Chowk": (1,-2),
    #Intersection (Blue-Green)
    "Park Street": (-7, -2),
    "Maidan": (-7, -3),
    "Rabindra Sadan": (-7, -4),
    "Netaji Bhavan": (-7, -5),
    "Jatin Das Park": (-7, -6),
    "Kalighat": (-7, -7),
    "Rabindra Sarovar": (-7, -8),
    "Mahanayak Uttam Kumar": (-7, -9),
    "Netaji": (-7, -10),
    "Masterda Surya Sen": (-7, -11),
    "Gitanjali": (-7, -12),
    "Kavi Nazrul": (-7, -13),
    "Shahid Khudiram": (-7, -14),
    "Kavi Subhas": (-7, -15),
    #End of Blue
    #Start of Purple
    "Joka": (-4,4),
    "Thakurpukur": (-4,5),
    "Sakherbazar": (-4,6),
    "Behala Chowrasta": (-4,7),
    "Behala Bazar": (-4,8),
    "Taratala": (-4,9),
    "Majerhat": (-4,10),
    #End of Purple
    #Start of Orange
    "Kavi Subhas":(-7,-15),
    "Satyajit Ray":(-11,-14),
    "Jyotirindra Nath Nandy":(-11,-13),
    "Kavi Sukanta":(-11,-12),
    "Hemanta Mukherjee":(-11,-11),
    #End of Orange
}

edge_colors = [G[u][v]['color'] for u, v in G.edges()]
plt.figure(figsize=(16,16))
nx.draw_networkx_nodes(G, pos, node_size=50)
nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=2)


'''for node, (x, y) in pos.items():
    plt.text(x, y, node, fontsize=8, ha='left', va='bottom')
'''

for node, (x, y) in pos.items():
    if node in [n[0] for n in green_line]:
        plt.text(x - 0.1, y-0.3, node, fontsize=10, ha='right', va='bottom')
    elif node in [n[0] for n in blue_line]:
        plt.text(x + 0.1, y-0.3, node, fontsize=10, ha='left', va='top')
    elif node in [n[0] for n in purple_line]:
        plt.text(x-0.1, y, node, fontsize=10, ha='right', va='top')
    elif node in [n[0] for n in orange_line]:
        plt.text(x-0.1, y, node, fontsize=10, ha='right', va='top')


plt.axis('off')
plt.xlim(-25,25)
plt.ylim(-25,25)
plt.show()

plt.savefig("Kolkata_Metro_Map.jpg", dpi=3000, bbox_inches='tight')
